# %%
import pandas as pd

# %%
a = pd.DataFrame(
        {"ㄱ" : [1 ,2, 3, 4],
        "ㄴ" : [5, 6, 7, 8],
        "ㄷ" : [9, 10, 11, 12]},
        index = [1, 2, 3, 4])

# %%
a
# Out:
#    ㄱ  ㄴ   ㄷ
# 1  1  5   9
# 2  2  6  10
# 3  3  7  11
# 4  4  8  12

# %%
a = pd.DataFrame(
        [[1 ,5, 9],
        [2, 6, 10],
        [3, 7, 11],
        [4, 8 ,12]],
        index = [1, 2, 3, 4],
        columns=['ㄱ', 'ㄴ', 'ㄷ'])
a
# Out:
#    ㄱ  ㄴ   ㄷ
# 1  1  5   9
# 2  2  6  10
# 3  3  7  11
# 4  4  8  12

# %%
a = pd.DataFrame(
    {"ㄱ" : [1 ,2, 3, 4],
        "ㄴ" : [5, 6, 7, 8],
        "ㄷ" : [9, 10, 11, 12]},
    index = pd.MultiIndex.from_tuples(
        [('k', 9), ('l', 7), ('m', 5), ('n', 6)],
        names=['M', 'U']))
a
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# k 9  1  5   9
# l 7  2  6  10
# m 5  3  7  11
# n 6  4  8  12

# %%
a.sort_values('ㄱ', ascending=False)
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# n 6  4  8  12
# m 5  3  7  11
# l 7  2  6  10
# k 9  1  5   9

# %%
a.rename(columns = {'ㄴ':'ㅁ'})
# Out:
#      ㄱ  ㅁ   ㄷ
# M U
# k 9  1  5   9
# l 7  2  6  10
# m 5  3  7  11
# n 6  4  8  12

# %%
a.reset_index()
# Out:
#    M  U  ㄱ  ㄴ   ㄷ
# 0  k  9  1  5   9
# 1  l  7  2  6  10
# 2  m  5  3  7  11
# 3  n  6  4  8  12

# %%
a.sort_index()
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# k 9  1  5   9
# l 7  2  6  10
# m 5  3  7  11
# n 6  4  8  12

# %%
a.drop(columns=['ㄱ', 'ㄴ'])
# Out:
#       ㄷ
# M U
# k 9   9
# l 7  10
# m 5  11
# n 6  12

# %%
a.head(2)
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# k 9  1  5   9
# l 7  2  6  10

# %%
a.tail(2)
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# m 5  3  7  11
# n 6  4  8  12

# %%
a[a["ㄱ"] > 2]
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# m 5  3  7  11
# n 6  4  8  12

# %%
a[a["ㄱ"] != 3]
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# k 9  1  5   9
# l 7  2  6  10
# n 6  4  8  12

# %%
a[a["ㄱ"] == 6]
# Out:
# Empty DataFrame
# Columns: [ㄱ, ㄴ, ㄷ]
# Index: []

# %%
a[a["ㄱ"] != 3]
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# k 9  1  5   9
# l 7  2  6  10
# n 6  4  8  12

# %%
a[a['ㄱ'].isin([4])]
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# n 6  4  8  12

# %%
a.sample(frac=0.75)
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# k 9  1  5   9
# l 7  2  6  10
# n 6  4  8  12

# %%
a.sample(n=3)
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# n 6  4  8  12
# m 5  3  7  11
# k 9  1  5   9

# %%
a.nlargest(3,'ㄱ')
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# n 6  4  8  12
# m 5  3  7  11
# l 7  2  6  10

# %%
df.nsmallest(3,'ㄱ')
# Out:
#    ㄱ  ㄴ   ㄷ
# 1  1  5   9
# 2  2  6  10
# 3  3  7  11

# %%
a.iloc[1:4]
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# l 7  2  6  10
# m 5  3  7  11
# n 6  4  8  12

# %%
a.iloc[2:]
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# m 5  3  7  11
# n 6  4  8  12

# %%
a.iloc[:3]
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# k 9  1  5   9
# l 7  2  6  10
# m 5  3  7  11

# %%
a.iloc[:]
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# k 9  1  5   9
# l 7  2  6  10
# m 5  3  7  11
# n 6  4  8  12

# %%
a[['ㄱ', 'ㄴ']]
# Out:
#      ㄱ  ㄴ
# M U
# k 9  1  5
# l 7  2  6
# m 5  3  7
# n 6  4  8

# %%
a.filter(regex='c')
# Out:
# Empty DataFrame
# Columns: []
# Index: [(k, 9), (l, 7), (m, 5), (n, 6)]

# %%
a.filter(regex='^(?!ㄷ$).*')
# Out:
#      ㄱ  ㄴ
# M U
# k 9  1  5
# l 7  2  6
# m 5  3  7
# n 6  4  8

# %%
a.loc[:, 'ㄱ':'ㄷ']
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# k 9  1  5   9
# l 7  2  6  10
# m 5  3  7  11
# n 6  4  8  12

# %%
a.iloc[0:3, [0, 2]]
# Out:
#      ㄱ   ㄷ
# M U
# k 9  1   9
# l 7  2  10
# m 5  3  11

# %%
a.loc[a['ㄱ'] > 3, ['ㄱ', 'ㄷ']]
# Out:
#      ㄱ   ㄷ
# M U
# n 6  4  12

# %%
a.iat[1, 2]
# Out:
# 10

# %%
a = pd.DataFrame(
    {"ㄱ" : [1 ,2, 3, 4, 4],
     "ㄴ" : [5, 6, 7, 8, 8],
     "ㄷ" : [9, 10, 11, 12, 12]},
    index = pd.MultiIndex.from_tuples(
        [('k', 9), ('l', 6), ('m', 5), ('n', 6), ('n',6)],
        names=['M', 'U']))
a
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# k 9  1  5   9
# l 6  2  6  10
# m 5  3  7  11
# n 6  4  8  12
#   6  4  8  12

# %%
a['ㄱ'].value_counts()
# Out:
# 4    2
# 1    1
# 2    1
# 3    1
# Name: ㄱ, dtype: int64

# %%
b = pd.DataFrame(
    {"ㄱ" : [1 ,2, 4, 6],
     "ㄴ" : [5, 6, 7, 8],},
    index = pd.MultiIndex.from_tuples(
        [('l', 6), ('m', 5), ('n', 6), ('n',6)],
        names=['M', 'U']))
len(b)
# Out:
# 4

# %%
b.shape
# Out:
# (4, 2)

# %%
b['ㄴ'].nunique()
# Out:
# 4

# %%
a.describe()
# Out:
#               ㄱ         ㄴ          ㄷ
# count  4.000000  4.000000   4.000000
# mean   2.500000  6.500000  10.500000
# std    1.290994  1.290994   1.290994
# min    1.000000  5.000000   9.000000
# 25%    1.750000  5.750000   9.750000
# 50%    2.500000  6.500000  10.500000
# 75%    3.250000  7.250000  11.250000
# max    4.000000  8.000000  12.000000

# %%
a = a.drop_duplicates()
a
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# k 9  1  5   9
# l 6  2  6  10
# m 5  3  7  11
# n 6  4  8  12

# %%
a.sum()
# Out:
# ㄱ    10
# ㄴ    26
# ㄷ    42
# dtype: int64

# %%
b.count()
# Out:
# ㄱ    4
# ㄴ    4
# dtype: int64

# %%
a.median()
# Out:
# ㄱ     2.5
# ㄴ     6.5
# ㄷ    10.5
# dtype: float64

# %%
a['ㄱ'].mean()
# Out:
# 2.5

# %%
a.quantile([0.25,0.75])
# Out:
#          ㄱ     ㄴ      ㄷ
# 0.25  1.75  5.75   9.75
# 0.75  3.25  7.25  11.25

# %%
a.min()
# Out:
# ㄱ    1
# ㄴ    5
# ㄷ    9
# dtype: int64

# %%
a.max()
# Out:
# ㄱ     4
# ㄴ     8
# ㄷ    12
# dtype: int64

# %%
a.std()
# Out:
# ㄱ    1.290994
# ㄴ    1.290994
# ㄷ    1.290994
# dtype: float64

# %%
import numpy as np
a.apply(np.sqrt)
# Out:
#             ㄱ         ㄴ         ㄷ
# M U
# k 9  1.000000  2.236068  3.000000
# l 6  1.414214  2.449490  3.162278
# m 5  1.732051  2.645751  3.316625
# n 6  2.000000  2.828427  3.464102

# %%
a = a = pd.DataFrame(
    {"ㄱ" : [1 ,np.nan, 3, 4],
        "ㄴ" : [5, 6, np.nan, 8],
        "ㄷ" : [np.nan, 10, 11, 12]},
    index = pd.MultiIndex.from_tuples(
        [('k', 9), ('l', 7), ('m', 5), ('n', 6)],
        names=['M', 'U']))
a
# Out:
#        ㄱ    ㄴ     ㄷ
# M U
# k 9  1.0  5.0   NaN
# l 7  NaN  6.0  10.0
# m 5  3.0  NaN  11.0
# n 6  4.0  8.0  12.0

# %%
pd.isnull(a)
# Out:
#          ㄱ      ㄴ      ㄷ
# M U
# k 9  False  False   True
# l 7   True  False  False
# m 5  False   True  False
# n 6  False  False  False

# %%
pd.notnull(a)
# Out:
#          ㄱ      ㄴ      ㄷ
# M U
# k 9   True   True  False
# l 7  False   True   True
# m 5   True  False   True
# n 6   True   True   True

# %%
a_notnull = a.dropna()
a_notnull
# Out:
#        ㄱ    ㄴ     ㄷ
# M U
# n 6  4.0  8.0  12.0

# %%
a_fillna = a.fillna(14)
a_fillna
# Out:
#         ㄱ     ㄴ     ㄷ
# M U
# k 9   1.0   5.0  14.0
# l 7  14.0   6.0  10.0
# m 5   3.0  14.0  11.0
# n 6   4.0   8.0  12.0

# %%
a_fillna_mean = a.fillna(a['ㄱ'].mean())
a_fillna_mean
# Out:
#             ㄱ         ㄴ          ㄷ
# M U
# k 9  1.000000  5.000000   2.666667
# l 7  2.666667  6.000000  10.000000
# m 5  3.000000  2.666667  11.000000
# n 6  4.000000  8.000000  12.000000

# %%
a = pd.DataFrame(
    {"ㄱ" : [1 ,2, 3, 4],
        "ㄴ" : [5, 6, 7, 8],
        "ㄷ" : [9, 10, 11, 12]},
    index = pd.MultiIndex.from_tuples(
        [('k', 9), ('l', 7), ('m', 5), ('n', 6)],
        names=['M', 'U']))
a
# Out:
#      ㄱ  ㄴ   ㄷ
# M U
# k 9  1  5   9
# l 7  2  6  10
# m 5  3  7  11
# n 6  4  8  12

# %%
a['sum'] = a['ㄱ']+a['ㄴ']+a['ㄷ']
a
# Out:
#      ㄱ  ㄴ   ㄷ  sum
# M U
# k 9  1  5   9   15
# l 7  2  6  10   18
# m 5  3  7  11   21
# n 6  4  8  12   24

# %%
a = a.assign(multiply=lambda a: a['ㄱ']*a['ㄴ']*a['ㄷ'])
a
# Out:
#      ㄱ  ㄴ   ㄷ  sum  multiply
# M U
# k 9  1  5   9   15        45
# l 7  2  6  10   18       120
# m 5  3  7  11   21       231
# n 6  4  8  12   24       384

# %%
a['qcut'] = pd.qcut(a['ㄱ'], 2, labels=["600이하","600이상"])
a
# Out:
#      ㄱ  ㄴ   ㄷ  sum  multiply   qcut
# M U
# k 9  1  5   9   15        45  600이하
# l 7  2  6  10   18       120  600이하
# m 5  3  7  11   21       231  600이상
# n 6  4  8  12   24       384  600이상

# %%
a['clip'] = a['ㄱ'].clip(lower=2,upper=3)
a
# Out:
#      ㄱ  ㄴ   ㄷ  sum  multiply   qcut  clip
# M U
# k 9  1  5   9   15        45  600이하     2
# l 7  2  6  10   18       120  600이하     2
# m 5  3  7  11   21       231  600이상     3
# n 6  4  8  12   24       384  600이상     3

# %%
a.max(axis=0)
# Out:
# ㄱ               4
# ㄴ               8
# ㄷ              12
# sum            24
# multiply      384
# qcut        600이상
# clip            3
# dtype: object

# %%
a.min(axis=0)
# Out:
# ㄱ               1
# ㄴ               5
# ㄷ               9
# sum            15
# multiply       45
# qcut        600이하
# clip            2
# dtype: object

# %%
a = pd.DataFrame({'ㄱ': {0: 'f', 1: 'g', 2: 'h'},
                   'ㄴ': {0: 4, 1: 2, 2: 1},
                   'ㄷ': {0: 2, 1: 4, 2: 5}})
a
# Out:
#    ㄱ  ㄴ  ㄷ
# 0  f  4  2
# 1  g  2  4
# 2  h  1  5

# %%
pd.melt(a)
# Out:
#   variable value
# 0        ㄱ     f
# 1        ㄱ     g
# 2        ㄱ     h
# 3        ㄴ     4
# 4        ㄴ     2
# 5        ㄴ     1
# 6        ㄷ     2
# 7        ㄷ     4
# 8        ㄷ     5

# %%
pd.melt(a, id_vars=['ㄱ'], value_vars=['ㄴ'])
# Out:
#    ㄱ variable  value
# 0  f        ㄴ      4
# 1  g        ㄴ      2
# 2  h        ㄴ      1

# %%
a_melt = pd.melt(a, id_vars=['ㄱ'], value_vars=['ㄴ','ㄷ'])
a_melt
# Out:
#    ㄱ variable  value
# 0  f        ㄴ      4
# 1  g        ㄴ      2
# 2  h        ㄴ      1
# 3  f        ㄷ      2
# 4  g        ㄷ      4
# 5  h        ㄷ      5

# %%
a_pivot = a_melt.pivot(index='ㄱ', columns='variable', values='value')
a_pivot
# Out:
# variable  ㄴ  ㄷ
# ㄱ
# f         4  2
# g         2  4
# h         1  5

# %%
a_origin = a_pivot.reset_index()
a_origin.columns.name = None
a_origin
# Out:
#    ㄱ  ㄴ  ㄷ
# 0  f  4  2
# 1  g  2  4
# 2  h  1  5

# %%
s1 = pd.Series(['ㄱ', 'ㄴ'])
s1
# Out:
# 0    ㄱ
# 1    ㄴ
# dtype: object

# %%
s2 = pd.Series(['ㄷ', 'ㄹ'])
s2
# Out:
# 0    ㄷ
# 1    ㄹ
# dtype: object

# %%
pd.concat([s1, s2])
# Out:
# 0    ㄱ
# 1    ㄴ
# 0    ㄷ
# 1    ㄹ
# dtype: object

# %%
pd.concat([s1, s2],
          keys=['s1', 's2'],
          names=['Series name', 'Row ID'])
# Out:
# Series name  Row ID
# s1           0         ㄱ
#              1         ㄴ
# s2           0         ㄷ
#              1         ㄹ
# dtype: object

# %%
a1 = pd.DataFrame([['ㄱ', 3],
                    ['ㄷ', 4]],
                       columns=['letter', 'number'])
a1
# Out:
#   letter  number
# 0      ㄱ       3
# 1      ㄷ       4

# %%
a2 = pd.DataFrame([['ㄷ', 1],
                    ['ㄹ', 2]],
                   columns=['letter', 'number'])
a2
# Out:
#   letter  number
# 0      ㄷ       1
# 1      ㄹ       2

# %%
a3 = pd.DataFrame([['ㄷ', 1, 'kingkong'],
                    ['ㄹ', 2, 'puppy']],
                       columns=['letter', 'number', 'animal'])
a3
# Out:
#   letter  number    animal
# 0      ㄷ       1  kingkong
# 1      ㄹ       2     puppy

# %%
a4 = pd.DataFrame([['kingkong', '철수'],
                    ['puppy', '나훈아']],
                   columns=['animal', 'name'])
a4
# Out:
#      animal name
# 0  kingkong   철수
# 1     puppy  나훈아

# %%
pd.concat([a1, a2])
# Out:
#   letter  number
# 0      ㄱ       3
# 1      ㄷ       4
# 0      ㄷ       1
# 1      ㄹ       2

# %%
pd.concat([a1, a3])
# Out:
#   letter  number    animal
# 0      ㄱ       3       NaN
# 1      ㄷ       4       NaN
# 0      ㄷ       1  kingkong
# 1      ㄹ       2     puppy

# %%
pd.concat([a1, a3], join="inner")
# Out:
#   letter  number
# 0      ㄱ       3
# 1      ㄷ       4
# 0      ㄷ       1
# 1      ㄹ       2

# %%
pd.concat([a1, a4], axis=1)
# Out:
#   letter  number    animal name
# 0      ㄱ       3  kingkong   철수
# 1      ㄷ       4     puppy  나훈아

# %%
aa = pd.DataFrame({"y1" : ["ㄱ","ㄴ","ㄷ"],
                    "y2": [4,5,6]})
aa
# Out:
#   y1  y2
# 0  ㄱ   4
# 1  ㄴ   5
# 2  ㄷ   6

# %%
bb = pd.DataFrame({"y1" : ["ㄱ","ㄴ","ㅁ"],
                    "y2": ["F","T","T"]})
bb
# Out:
#   y1 y2
# 0  ㄱ  F
# 1  ㄴ  T
# 2  ㅁ  T

# %%
cc = pd.DataFrame({"y1" : ["ㄴ","ㄷ","ㅁ"],
                    "y2": [2,1,4]})
cc
# Out:
#   y1  y2
# 0  ㄴ   2
# 1  ㄷ   1
# 2  ㅁ   4

# %%
pd.merge(aa, bb, how='left', on='y1')
# Out:
#   y1  y2_x y2_y
# 0  ㄱ     4    F
# 1  ㄴ     5    T
# 2  ㄷ     6  NaN

# %%
aa[aa.y1.isin(bb.y1)]
# Out:
#   y1  y2
# 0  ㄱ   4
# 1  ㄴ   5

# %%
aa[~aa.y1.isin(bb.y1)]
# Out:
#   y1  y2
# 2  ㄷ   6

# %%
pd.merge(aa, cc)
# Out:
# Empty DataFrame
# Columns: [y1, y2]
# Index: []

# %%
pd.merge(aa, cc, how='outer')
# Out:
#   y1  y2
# 0  ㄱ   4
# 1  ㄴ   5
# 2  ㄷ   6
# 3  ㄴ   2
# 4  ㄷ   1
# 5  ㅁ   4

# %%
pd.merge(aa, cc, how='outer', indicator=True)
# Out:
#   y1  y2      _merge
# 0  ㄱ   4   left_only
# 1  ㄴ   5   left_only
# 2  ㄷ   6   left_only
# 3  ㄴ   2  right_only
# 4  ㄷ   1  right_only
# 5  ㅁ   4  right_only

# %%
pd.merge(aa, cc, how='outer', indicator=True).query('_merge == "left_only"')
# Out:
#   y1  y2     _merge
# 0  ㄱ   4  left_only
# 1  ㄴ   5  left_only
# 2  ㄷ   6  left_only

# %%
pd.merge(aa, cc, how='outer', indicator=True).query('_merge == "left_only"').drop(columns=['_merge'])
# Out:
#   y1  y2
# 0  ㄱ   4
# 1  ㄴ   5
# 2  ㄷ   6

# %%
a = pd.DataFrame(
        {"ㄱ" : [1 ,2, 3, 4],
        "ㄴ" : [5, 6, 7, 8],
        "ㄷ" : [9, 10, 11, 12]},
        index = [1, 2, 3, 4])
a
# Out:
#    ㄱ  ㄴ   ㄷ
# 1  1  5   9
# 2  2  6  10
# 3  3  7  11
# 4  4  8  12

# %%
a.shift(1)
# Out:
#      ㄱ    ㄴ     ㄷ
# 1  NaN  NaN   NaN
# 2  1.0  5.0   9.0
# 3  2.0  6.0  10.0
# 4  3.0  7.0  11.0

# %%
a.shift(-1)
# Out:
#      ㄱ    ㄴ     ㄷ
# 1  2.0  6.0  10.0
# 2  3.0  7.0  11.0
# 3  4.0  8.0  12.0
# 4  NaN  NaN   NaN

# %%
a.cumsum()
# Out:
#     ㄱ   ㄴ   ㄷ
# 1   1   5   9
# 2   3  11  19
# 3   6  18  30
# 4  10  26  42

# %%
a.cummax()
# Out:
#    ㄱ  ㄴ   ㄷ
# 1  1  5   9
# 2  2  6  10
# 3  3  7  11
# 4  4  8  12

# %%
a.cummin()
# Out:
#    ㄱ  ㄴ  ㄷ
# 1  1  5  9
# 2  1  5  9
# 3  1  5  9
# 4  1  5  9

# %%
a.cumprod()
# Out:
#     ㄱ     ㄴ      ㄷ
# 1   1     5      9
# 2   2    30     90
# 3   6   210    990
# 4  24  1680  11880
