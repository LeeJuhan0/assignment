# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical
import os


(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()


train_images = train_images.reshape(train_images.shape[0], 784).astype('float32') / 255
test_images = test_images.reshape(test_images.shape[0], 784).astype('float32') / 255

train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)


model = Sequential()
model.add(Dense(512, input_dim=784, activation='relu'))
model.add(Dense(256, activation='relu'))  # 추가 층
model.add(Dense(128, activation='relu'))  # 추가 층
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

.
MODEL_DIR = './data/model/'
if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)

modelpath = "./data/model/fashion_mnist_MLP.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)
.
history = model.fit(train_images, train_labels, validation_split=0.25, epochs=400, batch_size=200, verbose=0, callbacks=[early_stopping_callback, checkpointer])

print("\n Test Accuracy: %.4f" % (model.evaluate(test_images, test_labels)[1]))
# Out:
# Epoch 1: val_loss improved from inf to 0.41936, saving model to ./data/model/fashion_mnist_MLP.hdf5
#
# Epoch 2: val_loss improved from 0.41936 to 0.36678, saving model to ./data/model/fashion_mnist_MLP.hdf5
#
# Epoch 3: val_loss improved from 0.36678 to 0.34432, saving model to ./data/model/fashion_mnist_MLP.hdf5
#
# Epoch 4: val_loss improved from 0.34432 to 0.31953, saving model to ./data/model/fashion_mnist_MLP.hdf5
#
# Epoch 5: val_loss did not improve from 0.31953
#
# Epoch 6: val_loss improved from 0.31953 to 0.31530, saving model to ./data/model/fashion_mnist_MLP.hdf5
#
# Epoch 7: val_loss did not improve from 0.31530
#
# Epoch 8: val_loss did not improve from 0.31530
#
# Epoch 9: val_loss did not improve from 0.31530
#
# Epoch 10: val_loss did not improve from 0.31530
#
# Epoch 11: val_loss improved from 0.31530 to 0.30807, saving model to ./data/model/fashion_mnist_MLP.hdf5
#
# Epoch 12: val_loss did not improve from 0.30807
#
# Epoch 13: val_loss did not improve from 0.30807
#
# Epoch 14: val_loss did not improve from 0.30807
#
# Epoch 15: val_loss did not improve from 0.30807
#
# Epoch 16: val_loss did not improve from 0.30807
#
# Epoch 17: val_loss did not improve from 0.30807
#
# Epoch 18: val_loss did not improve from 0.30807
#
# Epoch 19: val_loss did not improve from 0.30807
#
# Epoch 20: val_loss did not improve from 0.30807
#
# Epoch 21: val_loss did not improve from 0.30807
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3808 - accuracy: 0.8868
#
#  Test Accuracy: 0.8868

# %%
#CNN

import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical


(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()


train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32') / 255
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1).astype('float32') / 255
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)


model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), input_shape=(28, 28, 1), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))


model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

MODEL_DIR = './data/model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

modelpath = "./data/model/Fashion_MNIST_CNN.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

history = model.fit(train_images, train_labels, validation_split=0.25, epochs=30, batch_size=200, verbose=0, callbacks=[early_stopping_callback, checkpointer])

print("\n Test Accuracy: %.4f" % (model.evaluate(test_images, test_labels)[1]))
# Out:
# Epoch 1: val_loss improved from inf to 0.36860, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 0.36860 to 0.31074, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 3: val_loss improved from 0.31074 to 0.27418, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 4: val_loss improved from 0.27418 to 0.25851, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 5: val_loss improved from 0.25851 to 0.23951, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 6: val_loss improved from 0.23951 to 0.22716, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 7: val_loss improved from 0.22716 to 0.21955, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 8: val_loss improved from 0.21955 to 0.21507, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 9: val_loss improved from 0.21507 to 0.21504, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 10: val_loss did not improve from 0.21504
#
# Epoch 11: val_loss improved from 0.21504 to 0.20878, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 12: val_loss improved from 0.20878 to 0.20672, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 13: val_loss did not improve from 0.20672
#
# Epoch 14: val_loss did not improve from 0.20672
#
# Epoch 15: val_loss did not improve from 0.20672
#
# Epoch 16: val_loss did not improve from 0.20672
#
# Epoch 17: val_loss did not improve from 0.20672
#
# Epoch 18: val_loss did not improve from 0.20672
#
# Epoch 19: val_loss did not improve from 0.20672
#
# Epoch 20: val_loss did not improve from 0.20672
#
# Epoch 21: val_loss did not improve from 0.20672
#
# Epoch 22: val_loss did not improve from 0.20672
# 313/313 [==============================] - 8s 26ms/step - loss: 0.2455 - accuracy: 0.9258
#
#  Test Accuracy: 0.9258

# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical


(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()


train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32') / 255
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1).astype('float32') / 255
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)


model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), input_shape=(28, 28, 1), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))


model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

MODEL_DIR = './data/model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

modelpath = "./data/model/Fashion_MNIST_CNN.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

history = model.fit(train_images, train_labels, validation_split=0.25, epochs=40, batch_size=70, verbose=0, callbacks=[early_stopping_callback, checkpointer])

print("\n Test Accuracy: %.4f" % (model.evaluate(test_images, test_labels)[1]))
# Out:
# Epoch 1: val_loss improved from inf to 0.33142, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 2: val_loss improved from 0.33142 to 0.27723, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 3: val_loss improved from 0.27723 to 0.26590, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 4: val_loss improved from 0.26590 to 0.24761, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 5: val_loss improved from 0.24761 to 0.23769, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 6: val_loss improved from 0.23769 to 0.21458, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 7: val_loss did not improve from 0.21458
#
# Epoch 8: val_loss improved from 0.21458 to 0.21133, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 9: val_loss improved from 0.21133 to 0.20547, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 10: val_loss did not improve from 0.20547
#
# Epoch 11: val_loss did not improve from 0.20547
#
# Epoch 12: val_loss did not improve from 0.20547
#
# Epoch 13: val_loss did not improve from 0.20547
#
# Epoch 14: val_loss did not improve from 0.20547
#
# Epoch 15: val_loss did not improve from 0.20547
#
# Epoch 16: val_loss did not improve from 0.20547
#
# Epoch 17: val_loss did not improve from 0.20547
#
# Epoch 18: val_loss did not improve from 0.20547
#
# Epoch 19: val_loss did not improve from 0.20547
# 313/313 [==============================] - 8s 25ms/step - loss: 0.2619 - accuracy: 0.9244
#
#  Test Accuracy: 0.9244

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), input_shape=(28, 28, 1), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32') / 255
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1).astype('float32') / 255
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), input_shape=(28, 28, 1), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))


model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

MODEL_DIR = './data/model/'
os.makedirs(MODEL_DIR, exist_ok=True)

modelpath = "./data/model/Fashion_MNIST_CNN.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

history = model.fit(train_images, train_labels, validation_split=0.25, epochs=30, batch_size=200, verbose=0, callbacks=[early_stopping_callback, checkpointer])

print("\n 테스트 정확도: %.4f" % (model.evaluate(test_images, test_labels)[1]))
# Out:
# Epoch 1: val_loss improved from inf to 0.40103, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 2: val_loss improved from 0.40103 to 0.35014, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 3: val_loss improved from 0.35014 to 0.30356, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 4: val_loss improved from 0.30356 to 0.27588, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 5: val_loss improved from 0.27588 to 0.25666, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 6: val_loss improved from 0.25666 to 0.24138, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 7: val_loss improved from 0.24138 to 0.22978, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 8: val_loss improved from 0.22978 to 0.22586, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 9: val_loss improved from 0.22586 to 0.22093, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 10: val_loss improved from 0.22093 to 0.21631, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 11: val_loss did not improve from 0.21631
#
# Epoch 12: val_loss improved from 0.21631 to 0.21584, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 13: val_loss did not improve from 0.21584
#
# Epoch 14: val_loss did not improve from 0.21584
#
# Epoch 15: val_loss improved from 0.21584 to 0.21440, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 16: val_loss improved from 0.21440 to 0.21349, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 17: val_loss improved from 0.21349 to 0.21277, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 18: val_loss did not improve from 0.21277
#
# Epoch 19: val_loss did not improve from 0.21277
#
# Epoch 20: val_loss improved from 0.21277 to 0.21152, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 21: val_loss did not improve from 0.21152
#
# Epoch 22: val_loss did not improve from 0.21152
#
# Epoch 23: val_loss did not improve from 0.21152
#
# Epoch 24: val_loss did not improve from 0.21152
#
# Epoch 25: val_loss did not improve from 0.21152
#
# Epoch 26: val_loss did not improve from 0.21152
#
# Epoch 27: val_loss did not improve from 0.21152
#
# Epoch 28: val_loss did not improve from 0.21152
#
# Epoch 29: val_loss did not improve from 0.21152
#
# Epoch 30: val_loss did not improve from 0.21152
# 313/313 [==============================] - 10s 33ms/step - loss: 0.2688 - accuracy: 0.9245
#
#  테스트 정확도: 0.9245

# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32') / 255
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1).astype('float32') / 255
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), input_shape=(28, 28, 1), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))


model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

MODEL_DIR = './data/model/'
os.makedirs(MODEL_DIR, exist_ok=True)

modelpath = "./data/model/Fashion_MNIST_CNN.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

history = model.fit(train_images, train_labels, validation_split=0.25, epochs=50, batch_size=70, verbose=0, callbacks=[early_stopping_callback, checkpointer])

print("\n 테스트 정확도: %.4f" % (model.evaluate(test_images, test_labels)[1]))
# Out:
# Epoch 1: val_loss improved from inf to 0.37582, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 2: val_loss improved from 0.37582 to 0.30523, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 3: val_loss improved from 0.30523 to 0.27247, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 4: val_loss improved from 0.27247 to 0.25182, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 5: val_loss improved from 0.25182 to 0.24239, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 6: val_loss did not improve from 0.24239
#
# Epoch 7: val_loss improved from 0.24239 to 0.22429, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 8: val_loss improved from 0.22429 to 0.21588, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 9: val_loss improved from 0.21588 to 0.21447, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 10: val_loss did not improve from 0.21447
#
# Epoch 11: val_loss improved from 0.21447 to 0.20911, saving model to ./data/model/Fashion_MNIST_CNN.hdf5
#
# Epoch 12: val_loss did not improve from 0.20911
#
# Epoch 13: val_loss did not improve from 0.20911
#
# Epoch 14: val_loss did not improve from 0.20911
#
# Epoch 15: val_loss did not improve from 0.20911
#
# Epoch 16: val_loss did not improve from 0.20911
#
# Epoch 17: val_loss did not improve from 0.20911
#
# Epoch 18: val_loss did not improve from 0.20911
#
# Epoch 19: val_loss did not improve from 0.20911
#
# Epoch 20: val_loss did not improve from 0.20911
#
# Epoch 21: val_loss did not improve from 0.20911
# 313/313 [==============================] - 9s 28ms/step - loss: 0.2649 - accuracy: 0.9242
#
#  테스트 정확도: 0.9242
